# %%
import pandas as pd
import numpy as np

# %%
#read csv or excel file
#data=data.pd.read_excel('my_file.xls',0)
data=pd.read_csv('./mobile_train.csv')
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1456     0          1.6         1   9       1          39    0.1
# 1            584     1          1.7         1   1       1          19    0.4
# 2           1166     0          1.5         1   0       1          43    0.8
# 3           1567     0          2.1         1   3       0          22    0.8
# 4           1035     0          0.5         1  14       1          49    0.3
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0         80        8  ...        815      1666  3998     6     3         13
# 1        199        4  ...        919      1343  3996    12     9         17
# 2         80        4  ...        205       603  3993     7     1          7
# 3        153        3  ...        190      1326  3991    15     2         10
# 4        178        2  ...        574      1171  3991    12     4         19
#
# ...

# %%
data.shape
# Out:
# (2000, 21)

# %%
data.info() # shown the non-null count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    1999 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          1996 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             1994 non-null   float64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
data.isnull().sum() # shown the null count
# Out:
# battery_power    0
# blue             0
# clock_speed      1
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            4
# mobile_wt        0
# n_cores          0
# pc               6
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
#data.describe(include='all')
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  1999.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.521511     0.509500     4.309500
# std       439.418206     0.5001     0.815538     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  1996.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.500752   140.825500     4.520500  ...
# std       0.499662    18.145715     0.287839    41.062612     2.287837  ...
# ...

# %%
#To drop a column
#data=data.drop('id',axis=1)

# %%
data=data.rename(columns={"blue":"bluetooth",
                         "fc":"fc_megapixel",
                         "pc":"pc_megapixel",
                         "m_dep":"m_depth"})

# %%
data.head()
# Out:
#    battery_power  bluetooth  clock_speed  dual_sim  fc_megapixel  four_g  \
# 0           1456          0          1.6         1             9       1
# 1            584          1          1.7         1             1       1
# 2           1166          0          1.5         1             0       1
# 3           1567          0          2.1         1             3       0
# 4           1035          0          0.5         1            14       1
#
#    int_memory  m_depth  mobile_wt  n_cores  ...  px_height  px_width   ram  \
# 0          39      0.1         80        8  ...        815      1666  3998
# 1          19      0.4        199        4  ...        919      1343  3996
# 2          43      0.8         80        4  ...        205       603  3993
# 3          22      0.8        153        3  ...        190      1326  3991
# 4          49      0.3        178        2  ...        574      1171  3991
#
#    sc_h  sc_w  talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
dupes=data.duplicated()
dupes.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
#numbers of duplicates rows
sum(dupes)
# Out:
# 0

# %%
#To drop duplicates
data=data.drop_duplicates()

# %%
# To find the count of nulls, also you can use data.isna().sum()
data.isnull().sum()
# Out:
# battery_power    0
# bluetooth        0
# clock_speed      1
# dual_sim         0
# fc_megapixel     0
# four_g           0
# int_memory       0
# m_depth          4
# mobile_wt        0
# n_cores          0
# pc_megapixel     6
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# fill null values with 0
data['clock_speed']=data['clock_speed'].fillna(0)
data.isnull().sum()
# Out:
# battery_power    0
# bluetooth        0
# clock_speed      0
# dual_sim         0
# fc_megapixel     0
# four_g           0
# int_memory       0
# m_depth          4
# mobile_wt        0
# n_cores          0
# pc_megapixel     6
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
#FYI: null values also a unique values
len(data['pc_megapixel'].unique())
# Out:
# 22

# %%
data['pc_megapixel']=data['pc_megapixel'].fillna(method='backfill')
len(data['pc_megapixel'].unique())
# Out:
# 21

# %%
data.isna().sum()
# Out:
# battery_power    0
# bluetooth        0
# clock_speed      0
# dual_sim         0
# fc_megapixel     0
# four_g           0
# int_memory       0
# m_depth          4
# mobile_wt        0
# n_cores          0
# pc_megapixel     0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
#fill nulls values with median of a column.
data['m_depth']=data['m_depth'].fillna(data['m_depth'].median())
data.isnull().sum()
# Out:
# battery_power    0
# bluetooth        0
# clock_speed      0
# dual_sim         0
# fc_megapixel     0
# four_g           0
# int_memory       0
# m_depth          0
# mobile_wt        0
# n_cores          0
# pc_megapixel     0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
#drop all records with null values
data=data.dropna()

# %%
#save the data set to CSV file. index=False to not include the index of data frame to the CSV file.
data.to_csv('mobile_data_cleaned.csv',index=False)
#data=pd.read_csv('./mobile_data_cleaned.csv')

# %%
# show CSV files in the current dirctory
import os
files = [f for f in os.listdir('.') if os.path.isfile(f)]
for f in files:
    extension = os.path.splitext(f)[1]
    if extension=='.csv':
        print(f)
# Out:
# housing.csv
# mobile_data_cleaned.csv
# mobile_train.csv
# music.csv
# titanic_processed.csv
# titanic_test.csv
# titanic_train.csv

# %%
# will create two data sets one for numeric data and the other for categorical data 
numeric_data=data.drop(['bluetooth','dual_sim','four_g','three_g','touch_screen','wifi','price_range'],axis=1)
numeric_data.head()
# Out:
#    battery_power  clock_speed  fc_megapixel  int_memory  m_depth  mobile_wt  \
# 0           1456          1.6             9          39      0.1         80
# 1            584          1.7             1          19      0.4        199
# 2           1166          1.5             0          43      0.8         80
# 3           1567          2.1             3          22      0.8        153
# 4           1035          0.5            14          49      0.3        178
#
#    n_cores  pc_megapixel  px_height  px_width   ram  sc_h  sc_w  talk_time
# 0        8          10.0        815      1666  3998     6     3         13
# 1        4           4.0        919      1343  3996    12     9         17
# 2        4           1.0        205       603  3993     7     1          7
# 3        3          19.0        190      1326  3991    15     2         10
# 4        2          15.0        574      1171  3991    12     4         19

# %%
categorical_data=data[['bluetooth','dual_sim','four_g','three_g','touch_screen','wifi','price_range']]
categorical_data.head()
# Out:
#    bluetooth  dual_sim  four_g  three_g  touch_screen  wifi  price_range
# 0          0         1       1        1             1     0            3
# 1          1         1       1        1             1     1            3
# 2          0         1       1        1             1     0            3
# 3          0         1       0        1             0     0            3
# 4          0         1       1        1             0     0            3

# %%
# Visualizing data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# set figure size
fig,ax=plt.subplots(figsize=(10,8))
sns.boxplot(y=numeric_data['ram']) #show the data in y axis
# Out:
# <AxesSubplot:ylabel='ram'>

# %%
fig,ax=plt.subplots(figsize=(10,8))
sns.boxplot(y=numeric_data['mobile_wt']) #show the data in y axis
# Out:
# <AxesSubplot:ylabel='mobile_wt'>

# %%
# will draw boxplot for all columns
fig,ax=plt.subplots(figsize=(10,8))
bp=sns.boxplot(data=numeric_data)
bp.set_xticklabels(bp.get_xticklabels(),rotation=90) # label rotation
# Out:
# [Text(0, 0, 'battery_power'),
#  Text(1, 0, 'clock_speed'),
#  Text(2, 0, 'fc_megapixel'),
#  Text(3, 0, 'int_memory'),
#  Text(4, 0, 'm_depth'),
#  Text(5, 0, 'mobile_wt'),
#  Text(6, 0, 'n_cores'),
#  Text(7, 0, 'pc_megapixel'),
#  Text(8, 0, 'px_height'),
#  Text(9, 0, 'px_width'),
#  Text(10, 0, 'ram'),
#  Text(11, 0, 'sc_h'),
#  Text(12, 0, 'sc_w'),
#  Text(13, 0, 'talk_time')]
